# %%
import pandas as pd

# %%
example = pd.read_csv('WEEK1_2018_RECEIVING_DATA.csv')

# %%
df = pd.DataFrame(example)

# %%
df
# Out:
#       Rk                Player  Team  Pos   Rec   Yds    Avg   Yds/G   Lng  \
# 0      1        Michael Thomas    NO   WR    16   180   11.3   180.0    35
# 1      2         Odell Beckham   NYG   WR    11   111   10.1   111.0    24
# 2      3           Julio Jones   ATL   WR    10   169   16.9   169.0    36
# 3      3      Emmanuel Sanders   DEN   WR    10   135   13.5   135.0   43T
# 4      5         Antonio Brown   PIT   WR     9    93   10.3    93.0   22T
# 5      5          Randall Cobb    GB   WR     9   142   15.8   142.0   75T
# 6      5            Jared Cook   OAK   TE     9   180   20.0   180.0    45
# 7      5         Melvin Gordon   LAC   RB     9   102   11.3   102.0    25
# 8      5          Alvin Kamara    NO   RB     9   112   12.4   112.0    35
# 9      5         Jalen Richard   OAK   RB     9    55    6.1    55.0     9
# 10    11        Nelson Agholor   PHI   WR     8    33    4.1    33.0    10
# ...
