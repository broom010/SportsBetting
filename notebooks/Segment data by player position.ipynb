# %%
import os
import numpy as np
import pandas as pd
import difflib
import copy

from sklearn import linear_model


os.chdir('C://Users/jimmy/SportsBetting/public_data/')

# %%
week_4_Receiving = pd.read_csv('WEEK4_DATA/WEEK4_2018_NFL_RECEIVING')
week_3_Receiving = pd.read_csv('WEEK3_DATA/WEEK3_2018_NFL_RECEIVING')
week_2_Receiving = pd.read_csv('WEEK2_DATA/WEEK2_2018_NFL_RECEIVING')
week_1_Receiving = pd.read_csv('WEEK1_DATA/WEEK1_2018_NFL_RECEIVING')

df_4_Rec = pd.DataFrame(week_4_Receiving)
df_3_Rec = pd.DataFrame(week_3_Receiving)
df_2_Rec = pd.DataFrame(week_2_Receiving)
df_1_Rec = pd.DataFrame(week_1_Receiving)

# %%
df_1_Rec.head(10)
# Out:
#              Player Team Position  Rec  Yds  TDs  Fumbles   FFP
# 0    Michael Thomas   NO       WR   16  180    1        1  38.0
# 1     Odell Beckham  NYG       WR   11  111    0        0  22.1
# 2       Julio Jones  ATL       WR   10  169    0        0  26.9
# 3  Emmanuel Sanders  DEN       WR   10  135    1        0  29.5
# 4     Antonio Brown  PIT       WR    9   93    1        0  24.3
# 5      Randall Cobb   GB       WR    9  142    1        0  29.2
# 6        Jared Cook  OAK       TE    9  180    0        0  27.0
# 7     Melvin Gordon  LAC       RB    9  102    0        0  19.2
# 8      Alvin Kamara   NO       RB    9  112    1        0  26.2
# 9     Jalen Richard  OAK       RB    9   55    0        0  14.5

# %%
df_1_WR = df_1_Rec[df_1_Rec.Position == 'WR']
df_2_WR = df_2_Rec[df_2_Rec.Position == 'WR']
df_3_WR = df_3_Rec[df_3_Rec.Position == 'WR']
df_4_WR = df_4_Rec[df_4_Rec.Position == 'WR']

df_2_WR.drop(df_2_WR.index[81], inplace=True)     # Fix Josh Doctson

# %%
temp = pd.merge(df_1_WR.iloc[:,[0,3,4,5,6]], df_2_WR.iloc[:,[0,3,4,5,6]] , how='outer', on=['Player'])

# %%
temp.index = temp.Player

# %%
temp2 = copy.copy(df_3_WR)
temp2.index = temp2.Player
temp2.iloc[:,[6,7]]
# Out:
#                           Fumbles   FFP
# Player
# Michael Thomas                0.0  22.9
# Jarvis Landry                 0.0   0.0
# Antonio Brown                 0.0  17.0
# JuJu Smith-Schuster           0.0  20.6
# Adam Thielen                  0.0  24.5
# Quincy Enunwa                 0.0   0.0
# Mike Evans                    0.0  25.7
# Nelson Agholor                0.0   6.4
# Odell Beckham                 0.0  19.9
# Julio Jones                   0.0  14.6
# Keenan Allen                  1.0   5.4
# DeAndre Hopkins               0.0  14.6
# Allen Robinson                0.0   8.0
# Emmanuel Sanders              0.0   8.8
# Golden Tate                   0.0  12.9
# Davante Adams                 0.0  18.2
# Randall Cobb                  1.0   4.2
# Kenny Golladay                0.0  17.3
# Brandin Cooks                 0.0  16.0
# Stefon Diggs                  0.0   5.7
# Phillip Dorsett               0.0   0.0
# Tyreek Hill                   0.0   7.1
# ...

# %%
temp2 = pd.merge(temp, temp2.iloc[:,[0,6,7]], how='inner', on=['Player'])
temp2
# Out:
# C:\Users\jimmy\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2963: FutureWarning: 'Player' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                     Player  Rec_x  Yds_x  TDs_x  Fumbles_x  Rec_y  Yds_y  \
# 0           Michael Thomas     16    180      1          1   12.0   89.0
# 1            Odell Beckham     11    111      0          0    4.0   51.0
# 2              Julio Jones     10    169      0          0    5.0   64.0
# 3         Emmanuel Sanders     10    135      1          0    4.0   96.0
# 4            Antonio Brown      9     93      1          0    9.0   67.0
# 5             Randall Cobb      9    142      1          0    4.0   30.0
# 6           Nelson Agholor      8     33      0          0    8.0   88.0
# 7             Keenan Allen      8    108      1          0    6.0   67.0
# ...

# %%
temp
